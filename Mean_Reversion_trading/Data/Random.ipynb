# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import yfinance as yf

# %%
tickers = ["AAPL", "MSFT", "GOOG", "AMZN"]
data = yf.download(tickers, start="2010-01-01", auto_adjust= True, actions = True)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
data.to_csv("/Users/matthewsoh/Library/CloudStorage/GoogleDrive-suhendramatthew@gmail.com/My Drive/Coding/Personal/Mean_Reversion_Trading.py/Data/SPY.csv")
